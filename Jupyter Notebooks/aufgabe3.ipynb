# %%
import math 

from ipycanvas import MultiCanvas, hold_canvas
from src.utils.helper import draw_line_with_strokes, abs_value, draw_arrow, ghetto_feder_daempfer_element_bottom, ghetto_feder_daempfer_element_top

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from src.gui.gui_aufgabe_3 import GUI
from src.anim.animations.aufgabe_3 import Aufgabe3
from src.calculations.int_solver import IntSolverAufgabe3

DEFAULT_C = 0.5
DEFAULT_D = 0.5
calculator = IntSolverAufgabe3()

animation_instance = Aufgabe3(calculator=calculator)
app = GUI(default_c=DEFAULT_C,
        default_d=DEFAULT_D,
        animation_instance=animation_instance)
display(app.app_layout)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# AppLayout(children=(GridspecLayout(children=(HTML(value='<strong style="font-family: Arial, sans-serif;">Varia…
